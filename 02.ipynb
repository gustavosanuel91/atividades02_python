# %%
login_usuario = input("Digite o nome de usuario: ").lower()
login_senha = int(input("Digite sua senha: "))

if login_usuario == "admin":
    if login_senha == 1234:
        print("\n=====| lOGIN REALIZADO COM SUCESSO! |=====\n")
    else:
        print("\n=====| SENHA INVALIDA! |=====\n")
else:
    print("\n=====| USUARIO INVALIDO! |=====\n")
