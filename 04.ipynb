# %%
n1 = int(input("Digite um numero: "))

if n1 >= 0:
    if n1 % 2 == 0:
        print("\n=====| PAR POSITIVO! |=====\n")
    else:
        print("\n=====| IMPAR POSITIVO! |=====\n")
else:
    print("\n=====| NUMERO NEGATIVO! |=====\n")
